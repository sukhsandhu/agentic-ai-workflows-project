# %% [markdown]
# # Agentic AI Workflow Execution Notebook
#
# This notebook wrapper runs the same submitted implementation in `agentic_system.py` so the project is available in both accepted Udacity formats.

# %%
from agentic_system import run_demo

results = run_demo()
results
# Out:
# {
#   "scenario_count": 4,
#   "decisions": [
#     "standard_queue",
#     "expedited_human_review",
#     "human_review_required",
#     "manual_data_quality_review"
#   ],
#   "first_scenario": {
#     "case_id": "CASE-001",
#     "decision": "standard_queue",
#     "reason": "Signals are within operational thresholds.",
#     "priority_score": 0.21,
#     "quality_risk": 0.0,
#     "trace": [
#       {
#         "step": "initialize",
#         "case_id": "CASE-001"
#       },
#       {
#         "step": "tool:data_quality",
#         "observation": {
#           "missing_count": 0,
#           "quality_risk": 0.0,
#           "missing_fields": []
#         }
#       },
#       {
#         "step": "tool:policy_lookup",
#         "observation": {
#           "constraint": "internal_review_allowed",
#           "reason": "internal operations case"
#         }
#       },
#       {
#         "step": "tool:priority",
#         "observation": {
#           "priority_score": 0.21
# ...

# %% [markdown]
# ## Summary
#
# The workflow initializes a semi-autonomous healthcare triage agent, applies decision logic with policy constraints, stores observable state, invokes deterministic support tools, and records execution outputs for review. The script file remains the authoritative implementation and this notebook provides a convenient rerun surface.
